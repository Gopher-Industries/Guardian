# %%
pip install faker
# Out:
# Requirement already satisfied: faker in /home/unix_david/anaconda3/lib/python3.12/site-packages (37.3.0)
# Requirement already satisfied: tzdata in /home/unix_david/anaconda3/lib/python3.12/site-packages (from faker) (2023.3)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
"""
generate_nurse_reports.py
-------------------------------------------------
Creates a CSV of synthetic nurse shift reports for
NLP experiments (summarisation, anomaly detection, etc.).
No paid API or cloud service required.

Author: (your name)
"""

from faker import Faker
import numpy as np
import pandas as pd
import random
import datetime as dt
import textwrap

# ------------------------------------------------------------------
# 1.  Initial setup
# ------------------------------------------------------------------
SEED = 42                       # Re-run with the same seed for identical output
random.seed(SEED)
np.random.seed(SEED)
fake = Faker("en_AU")           # Australian dates/spelling
Faker.seed(SEED)

# ------------------------------------------------------------------
# 2.  Vocabulary pools – edit to match your clinical context
# ------------------------------------------------------------------
WARDS = ["Cardiology", "Oncology", "Orthopaedics", "ICU"]
SHIFTS = ["AM", "PM", "Night"]
CONDITIONS = [
    "post-op knee replacement",
    "COPD exacerbation",
    "diabetic ketoacidosis",
    "sepsis",
    "stroke"
]
ACTIONS = [
    "administered IV antibiotics",
    "changed wound dressing",
    "mobilised with physiotherapist",
    "monitored blood glucose",
    "provided education on inhaler use"
]
VITALS = [
    "within normal range",
    "BP slightly elevated",
    "tachycardic overnight",
    "SpO₂ 92 % on room air"
]
PLANS = [
    "continue current antibiotics",
    "review analgesia",
    "chase blood culture results",
    "physio to assess mobility"
]

# ------------------------------------------------------------------
# 3.  Helper to build one patient paragraph
# ------------------------------------------------------------------
rng = np.random.default_rng(SEED)

def make_patient_block() -> str:
    """Return one paragraph describing a single patient."""
    alias  = f"P{rng.integers(1000, 1999)}"
    age    = rng.integers(25, 95)
    cond   = random.choice(CONDITIONS)
    action = random.choice(ACTIONS)
    vit    = random.choice(VITALS)
    plan   = random.choice(PLANS)

    return (
        f"{alias} ({age} y o) admitted with {cond}. "
        f"During shift, {action}. "
        f"Vitals {vit}. "
        f"Plan: {plan}."
    )

# ------------------------------------------------------------------
# 4.  Build an entire note (header + 1-n patient blocks + footer)
# ------------------------------------------------------------------
def generate_note(note_id: int) -> str:
    date   = fake.date_between(start_date="-14d", end_date="today")
    ward   = random.choice(WARDS)
    shift  = random.choice(SHIFTS)
    nurse  = fake.name()

    n_patients = max(1, rng.poisson(2))   # mean ≈ 2 patients per nurse
    patient_sections = "\n".join(make_patient_block() for _ in range(n_patients))

    footer = f"– {nurse.split()[0]} (RN)  {dt.datetime.now().strftime('%H:%M')}"

    note = textwrap.dedent(f"""
        ### Nurse Shift Report {note_id}
        Date: {date}    Shift: {shift}    Ward: {ward}
        ------------------------------------------------------------
        {patient_sections}
        ------------------------------------------------------------
        {footer}
    """).strip()

    return note

# ------------------------------------------------------------------
# 5.  Build a whole dataset and save to disk
# ------------------------------------------------------------------
def build_dataset(n_notes: int = 500,
                  out_path: str = "synthetic_nurse_notes.csv") -> None:
    """Generate *n_notes* reports and write them to *out_path*."""
    notes = [generate_note(i + 1) for i in range(n_notes)]
    df = pd.DataFrame({"note_id": range(1, n_notes + 1), "text": notes})
    df.to_csv(out_path, index=False)
    print(f"✔  Saved {n_notes} notes to '{out_path}'")

# ------------------------------------------------------------------
# 6.  Script entry-point
# ------------------------------------------------------------------
if __name__ == "__main__":
    build_dataset(500, "synthetic_nurse_notes.csv")   # <-- adjust here if needed
# Out:
# ✔  Saved 500 notes to 'synthetic_nurse_notes.csv'

# %%
import pandas as pd

df = pd.read_csv("synthetic_nurse_notes.csv")    # ← points to the file you saved
print("\n=== Preview of first 20 synthetic notes ===")
print(df.head(20).to_string(index=False))
# Out:
# === Preview of first 20 synthetic notes ===
#  note_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 text
#        1                                                                                                                                                             ### Nurse Shift Report 1\n        Date: 2025-05-10    Shift: AM    Ward: Cardiology\n        ------------------------------------------------------------\n        P1525 (93 y o) admitted with diabetic ketoacidosis. During shift, changed wound dressing. Vitals BP slightly elevated. Plan: review analgesia.\nP1735 (78 y o) admitted with post-op knee replacement. During shift, provided education on inhaler use. Vitals within normal range. Plan: physio to assess mobility.\nP1716 (80 y o) admitted with post-op knee replacement. During shift, administered IV antibiotics. Vitals within normal range. Plan: review analgesia.\nP1512 (33 y o) admitted with COPD exacerbation. During shift, provided education on inhaler use. Vitals within normal range. Plan: review analgesia.\n        ------------------------------------------------------------\n        – Donald (RN)  12:49
#        2                                                                                                                                                                                                                                                                                                                         ### Nurse Shift Report 2\n        Date: 2025-05-12    Shift: AM    Ward: ICU\n        ------------------------------------------------------------\n        P1402 (82 y o) admitted with sepsis. During shift, provided education on inhaler use. Vitals tachycardic overnight. Plan: continue current antibiotics.\nP1544 (56 y o) admitted with COPD exacerbation. During shift, monitored blood glucose. Vitals tachycardic overnight. Plan: chase blood culture results.\nP1450 (40 y o) admitted with COPD exacerbation. During shift, changed wound dressing. Vitals tachycardic overnight. Plan: continue current antibiotics.\n        ------------------------------------------------------------\n        – Stephanie (RN)  12:49
#        3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ### Nurse Shift Report 3\nDate: 2025-05-07    Shift: PM    Ward: Cardiology\n------------------------------------------------------------\nP1857 (82 y o) admitted with post-op knee replacement. During shift, mobilised with physiotherapist. Vitals tachycardic overnight. Plan: chase blood culture results.\n------------------------------------------------------------\n– Daniel (RN)  12:49
#        4 ### Nurse Shift Report 4\n        Date: 2025-05-02    Shift: Night    Ward: Cardiology\n        ------------------------------------------------------------\n        P1759 (38 y o) admitted with sepsis. During shift, provided education on inhaler use. Vitals within normal range. Plan: physio to assess mobility.\nP1363 (57 y o) admitted with post-op knee replacement. During shift, provided education on inhaler use. Vitals tachycardic overnight. Plan: chase blood culture results.\nP1497 (28 y o) admitted with stroke. During shift, changed wound dressing. Vitals within normal range. Plan: continue current antibiotics.\nP1546 (35 y o) admitted with COPD exacerbation. During shift, mobilised with physiotherapist. Vitals within normal range. Plan: review analgesia.\nP1742 (72 y o) admitted with post-op knee replacement. During shift, monitored blood glucose. Vitals tachycardic overnight. Plan: physio to assess mobility.\n        ------------------------------------------------------------\n        – Matthew (RN)  12:49
#        5                                                                                                                                                                                                                                                                                                    ### Nurse Shift Report 5\n        Date: 2025-05-05    Shift: AM    Ward: Orthopaedics\n        ------------------------------------------------------------\n        P1076 (57 y o) admitted with diabetic ketoacidosis. During shift, mobilised with physiotherapist. Vitals BP slightly elevated. Plan: chase blood culture results.\nP1794 (38 y o) admitted with post-op knee replacement. During shift, provided education on inhaler use. Vitals BP slightly elevated. Plan: review analgesia.\nP1462 (34 y o) admitted with COPD exacerbation. During shift, monitored blood glucose. Vitals SpO₂ 92 % on room air. Plan: chase blood culture results.\n        ------------------------------------------------------------\n        – Rhonda (RN)  12:49
#        6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ### Nurse Shift Report 6\nDate: 2025-05-13    Shift: Night    Ward: Oncology\n------------------------------------------------------------\nP1563 (71 y o) admitted with diabetic ketoacidosis. During shift, administered IV antibiotics. Vitals BP slightly elevated. Plan: continue current antibiotics.\n------------------------------------------------------------\n– Gina (RN)  12:49
#        7                                                                                                                                                                                                                                                                                                                  ### Nurse Shift Report 7\n        Date: 2025-05-15    Shift: PM    Ward: Orthopaedics\n        ------------------------------------------------------------\n        P1767 (83 y o) admitted with diabetic ketoacidosis. During shift, administered IV antibiotics. Vitals BP slightly elevated. Plan: chase blood culture results.\nP1434 (81 y o) admitted with COPD exacerbation. During shift, monitored blood glucose. Vitals SpO₂ 92 % on room air. Plan: physio to assess mobility.\nP1840 (52 y o) admitted with COPD exacerbation. During shift, mobilised with physiotherapist. Vitals BP slightly elevated. Plan: review analgesia.\n        ------------------------------------------------------------\n        – Brandon (RN)  12:49
#        8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ### Nurse Shift Report 8\n        Date: 2025-05-13    Shift: Night    Ward: Orthopaedics\n        ------------------------------------------------------------\n        P1831 (38 y o) admitted with stroke. During shift, monitored blood glucose. Vitals SpO₂ 92 % on room air. Plan: chase blood culture results.\nP1804 (25 y o) admitted with COPD exacerbation. During shift, changed wound dressing. Vitals SpO₂ 92 % on room air. Plan: continue current antibiotics.\n        ------------------------------------------------------------\n        – Renee (RN)  12:49
#        9                                                                                                                                                                           ### Nurse Shift Report 9\n        Date: 2025-05-09    Shift: AM    Ward: Cardiology\n        ------------------------------------------------------------\n        P1505 (64 y o) admitted with COPD exacerbation. During shift, changed wound dressing. Vitals SpO₂ 92 % on room air. Plan: continue current antibiotics.\nP1037 (34 y o) admitted with sepsis. During shift, monitored blood glucose. Vitals SpO₂ 92 % on room air. Plan: chase blood culture results.\nP1245 (33 y o) admitted with stroke. During shift, administered IV antibiotics. Vitals within normal range. Plan: chase blood culture results.\nP1439 (71 y o) admitted with diabetic ketoacidosis. During shift, administered IV antibiotics. Vitals tachycardic overnight. Plan: physio to assess mobility.\n        ------------------------------------------------------------\n        – Jamie (RN)  12:49
#       10                                                                                                                                                                                                                                                                                                    ### Nurse Shift Report 10\n        Date: 2025-05-13    Shift: PM    Ward: Oncology\n        ------------------------------------------------------------\n        P1564 (63 y o) admitted with post-op knee replacement. During shift, mobilised with physiotherapist. Vitals BP slightly elevated. Plan: continue current antibiotics.\nP1090 (64 y o) admitted with diabetic ketoacidosis. During shift, provided education on inhaler use. Vitals BP slightly elevated. Plan: review analgesia.\nP1794 (46 y o) admitted with diabetic ketoacidosis. During shift, changed wound dressing. Vitals within normal range. Plan: chase blood culture results.\n        ------------------------------------------------------------\n        – Shannon (RN)  12:49
#       11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ### Nurse Shift Report 11\nDate: 2025-05-11    Shift: AM    Ward: ICU\n------------------------------------------------------------\nP1347 (55 y o) admitted with post-op knee replacement. During shift, mobilised with physiotherapist. Vitals tachycardic overnight. Plan: review analgesia.\n------------------------------------------------------------\n– Darren (RN)  12:49
#       12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ### Nurse Shift Report 12\nDate: 2025-05-03    Shift: AM    Ward: Cardiology\n------------------------------------------------------------\nP1991 (84 y o) admitted with stroke. During shift, administered IV antibiotics. Vitals within normal range. Plan: physio to assess mobility.\n------------------------------------------------------------\n– Brian (RN)  12:49
#       13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ### Nurse Shift Report 13\nDate: 2025-05-10    Shift: Night    Ward: Cardiology\n------------------------------------------------------------\nP1854 (44 y o) admitted with COPD exacerbation. During shift, changed wound dressing. Vitals SpO₂ 92 % on room air. Plan: review analgesia.\n------------------------------------------------------------\n– Jacob (RN)  12:49
#       14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ### Nurse Shift Report 14\n        Date: 2025-05-05    Shift: Night    Ward: Orthopaedics\n        ------------------------------------------------------------\n        P1504 (79 y o) admitted with stroke. During shift, monitored blood glucose. Vitals BP slightly elevated. Plan: review analgesia.\nP1995 (71 y o) admitted with diabetic ketoacidosis. During shift, monitored blood glucose. Vitals tachycardic overnight. Plan: physio to assess mobility.\n        ------------------------------------------------------------\n        – Maria (RN)  12:49
#       15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ### Nurse Shift Report 15\n        Date: 2025-05-04    Shift: AM    Ward: ICU\n        ------------------------------------------------------------\n        P1333 (26 y o) admitted with COPD exacerbation. During shift, changed wound dressing. Vitals within normal range. Plan: chase blood culture results.\nP1106 (31 y o) admitted with post-op knee replacement. During shift, provided education on inhaler use. Vitals BP slightly elevated. Plan: review analgesia.\n        ------------------------------------------------------------\n        – Carla (RN)  12:49
#       16                                                                                                                                                                                                                                                                                                                                                                                                                                                                ### Nurse Shift Report 16\n        Date: 2025-05-15    Shift: AM    Ward: Cardiology\n        ------------------------------------------------------------\n        P1899 (60 y o) admitted with post-op knee replacement. During shift, changed wound dressing. Vitals within normal range. Plan: continue current antibiotics.\nP1937 (35 y o) admitted with diabetic ketoacidosis. During shift, administered IV antibiotics. Vitals BP slightly elevated. Plan: chase blood culture results.\n        ------------------------------------------------------------\n        – Kristin (RN)  12:49
#       17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ### Nurse Shift Report 17\n        Date: 2025-05-13    Shift: AM    Ward: ICU\n        ------------------------------------------------------------\n        P1238 (46 y o) admitted with stroke. During shift, changed wound dressing. Vitals SpO₂ 92 % on room air. Plan: review analgesia.\nP1683 (69 y o) admitted with sepsis. During shift, monitored blood glucose. Vitals BP slightly elevated. Plan: continue current antibiotics.\n        ------------------------------------------------------------\n        – Crystal (RN)  12:49
#       18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ### Nurse Shift Report 18\nDate: 2025-05-06    Shift: Night    Ward: Cardiology\n------------------------------------------------------------\nP1342 (33 y o) admitted with sepsis. During shift, mobilised with physiotherapist. Vitals SpO₂ 92 % on room air. Plan: physio to assess mobility.\n------------------------------------------------------------\n– Daniel (RN)  12:49
#       19            ### Nurse Shift Report 19\n        Date: 2025-05-14    Shift: Night    Ward: ICU\n        ------------------------------------------------------------\n        P1260 (75 y o) admitted with post-op knee replacement. During shift, administered IV antibiotics. Vitals within normal range. Plan: physio to assess mobility.\nP1788 (56 y o) admitted with diabetic ketoacidosis. During shift, administered IV antibiotics. Vitals BP slightly elevated. Plan: review analgesia.\nP1736 (44 y o) admitted with COPD exacerbation. During shift, provided education on inhaler use. Vitals SpO₂ 92 % on room air. Plan: review analgesia.\nP1079 (31 y o) admitted with sepsis. During shift, changed wound dressing. Vitals tachycardic overnight. Plan: physio to assess mobility.\nP1446 (88 y o) admitted with COPD exacerbation. During shift, administered IV antibiotics. Vitals SpO₂ 92 % on room air. Plan: continue current antibiotics.\n        ------------------------------------------------------------\n        – Matthew (RN)  12:49
#       20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ### Nurse Shift Report 20\nDate: 2025-05-14    Shift: Night    Ward: Cardiology\n------------------------------------------------------------\nP1720 (46 y o) admitted with stroke. During shift, administered IV antibiotics. Vitals within normal range. Plan: review analgesia.\n------------------------------------------------------------\n– Derek (RN)  12:49

# %%
import pandas as pd
import re

df = pd.read_csv("synthetic_nurse_notes.csv")

# pull the YYYY-MM-DD that appears right after 'Date:'
df['date'] = pd.to_datetime(
    df['text'].str.extract(r'Date:\s*([\d-]+)')[0],   # first capture group
    format='%Y-%m-%d'
)

# now sort by date (and maybe by shift too, if you like)
df_sorted = df.sort_values('date', ascending=True)  # newest last

# preview
print("\n=== First 20 notes in DATE order ===")
print(df_sorted[['note_id', 'date']].head(20).to_string(index=False))
# Out:
# === First 20 notes in DATE order ===
#  note_id       date
#      296 2025-05-02
#      466 2025-05-02
#      240 2025-05-02
#      313 2025-05-02
#      123 2025-05-02
#      125 2025-05-02
#       26 2025-05-02
#      481 2025-05-02
#      341 2025-05-02
#       32 2025-05-02
#      487 2025-05-02
#      164 2025-05-02
#       35 2025-05-02
#      348 2025-05-02
#      294 2025-05-02
#      147 2025-05-02
#      117 2025-05-02
#      491 2025-05-02
#      120 2025-05-02
#      427 2025-05-02

# %%
for _, row in df_sorted.head(5).iterrows():   # change 5 to however many you want
    print("\n" + "="*80)
    print(row['text'])
# Out:
# ================================================================================
# ### Nurse Shift Report 296
# Date: 2025-05-02    Shift: AM    Ward: ICU
# ------------------------------------------------------------
# P1327 (62 y o) admitted with stroke. During shift, provided education on inhaler use. Vitals within normal range. Plan: physio to assess mobility.
# ------------------------------------------------------------
# – Robert (RN)  12:49
#
# ================================================================================
# ### Nurse Shift Report 466
# Date: 2025-05-02    Shift: Night    Ward: Cardiology
# ------------------------------------------------------------
# P1451 (73 y o) admitted with diabetic ketoacidosis. During shift, changed wound dressing. Vitals SpO₂ 92 % on room air. Plan: physio to assess mobility.
# ------------------------------------------------------------
# – Eric (RN)  12:49
#
# ================================================================================
# ### Nurse Shift Report 240
#         Date: 2025-05-02    Shift: PM    Ward: Oncology
#         ------------------------------------------------------------
#         P1414 (39 y o) admitted with diabetic ketoacidosis. During shift, monitored blood glucose. Vitals tachycardic overnight. Plan: physio to assess mobility.
# P1104 (54 y o) admitted with post-op knee replacement. During shift, mobilised with physiotherapist. Vitals tachycardic overnight. Plan: review analgesia.
#         ------------------------------------------------------------
#         – Kristina (RN)  12:49
#
# ================================================================================
# ### Nurse Shift Report 313
#         Date: 2025-05-02    Shift: AM    Ward: Orthopaedics
#         ------------------------------------------------------------
#         P1675 (25 y o) admitted with diabetic ketoacidosis. During shift, monitored blood glucose. Vitals within normal range. Plan: chase blood culture results.
# P1571 (64 y o) admitted with diabetic ketoacidosis. During shift, mobilised with physiotherapist. Vitals BP slightly elevated. Plan: review analgesia.
#         ------------------------------------------------------------
#         – Steven (RN)  12:49
#
# ================================================================================
# ### Nurse Shift Report 123
#         Date: 2025-05-02    Shift: PM    Ward: Cardiology
#         ------------------------------------------------------------
#         P1565 (25 y o) admitted with sepsis. During shift, mobilised with physiotherapist. Vitals tachycardic overnight. Plan: chase blood culture results.
# P1415 (44 y o) admitted with COPD exacerbation. During shift, monitored blood glucose. Vitals within normal range. Plan: continue current antibiotics.
#         ------------------------------------------------------------
#         – Michael (RN)  12:49
